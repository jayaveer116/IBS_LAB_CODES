# %% [markdown]
# BL.SC.U4AIE24224

# %% [markdown]
# JAYAVEER VENKATA SAI MADDALI

# %% [markdown]
# COMPLEMENT CODE

# %%
def complement(dna_sequence):
    complement = " "
    for base in dna_sequence:
        if base == 'A':
            complement += 'T'
        elif base == 'T':
            complement += 'A'
        elif base == 'C':
            complement += 'G'
        elif base == 'G':
            complement += 'C'
    return complement

dna_sequence = "ACGTCACGTGT"
print(complement(dna_sequence))
# Out:
#  TGCAGTGCACA

# %%
# !pip install biopython
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 47.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# USING BIOPYTHON

# %%
from Bio.Seq import Seq

my_dna=Seq("ACGTCACGTGT")

complement = my_dna.complement()

print("Original DNA Sequence:", my_dna)
print("Complement Sequence:", complement)
# Out:
# Original DNA Sequence: ACGTCACGTGT
# Complement Sequence: TGCAGTGCACA

# %% [markdown]
# **REVERSE** **COMPLEMENT**

# %%
dna = "ACGTCACGTGT"

complement = {
    "A": "T",
    "T": "A",
    "C": "G",
    "G": "C"
}

dna_complement = ""
for letter in dna:
  dna_complement=dna_complement+complement[letter]

print("3' -->5' ",dna_complement)

reverse_dna_complement = dna_complement[::-1]
print("5' -->3' ",reverse_dna_complement)
rna=reverse_dna_complement.replace("T","U")
print("5' -->3' ",rna)
# Out:
# TGCAGTGCACA
# ACACGTGACGT
# ACACGUGACGU

# %% [markdown]
# TRANSCRIPTION

# %%
def transcription(dna_sequence):
    transcription = " "
    for base in dna_sequence:
        if base == 'T':
            transcription += 'U'
        elif base == 'A':
            transcription += 'A'
        elif base == 'C':
            transcription += 'C'
        elif base == 'G':
            transcription += 'G'
    return transcription

dna_sequence = "ACGTCACGTGT"
print(transcription(dna_sequence))
# Out:
#  ACGUCACGUGU

# %% [markdown]
# USING BIOPYTHON

# %%
from Bio.Seq import Seq

my_dna=Seq("ACGTCACGTGT")

transcript = my_dna.transcribe()

print("Original DNA Sequence:", my_dna)
print("transcribed rna sequenceSequence:", transcript)
# Out:
# Original DNA Sequence: ACGTCACGTGT
# transcription Sequence: ACGUCACGUGU

# %% [markdown]
# CODON TABLE

# %%
def translate_rna_to_protein(rna_sequence):
  codon_table={
      'UUU': 'F', 'UUC': 'F', 'UUA': 'L', 'UUG': 'L',
      'UCU': 'S', 'UCC': 'S', 'UCA': 'S', 'UCG': 'S',
      'UAU': 'Y', 'UAC': 'Y', 'UAA': '*', 'UAG': '*',
      'UGU': 'C', 'UGC': 'C', 'UGA': '*', 'UGG': 'W',
      'CUU': 'L', 'CUC': 'L', 'CUA': 'L', 'CUG': 'L',
      'CCU': 'P', 'CCC': 'P', 'CCA': 'P', 'CCG': 'P',
      'CAU': 'H', 'CAC': 'H', 'CAA': 'Q', 'CAG': 'Q',
      'CGU': 'R', 'CGC': 'R', 'CGA': 'R', 'CGG': 'R',
      'AUU': 'I', 'AUC': 'I', 'AUA': 'I', 'AUG': 'M',
      'ACU': 'T', 'ACC': 'T', 'ACA': 'T', 'ACG': 'T',
      'AAU': 'N', 'AAC': 'N', 'AAA': 'K', 'AAG': 'K',
      'AGU': 'S', 'AGC': 'S', 'AGA': 'R', 'AGG': 'R',
      'GUU': 'V', 'GUC': 'V', 'GUA': 'V', 'GUG': 'V',
      'GCU': 'A', 'GCC': 'A', 'GCA': 'A', 'GCG': 'A',
      'GAU': 'D', 'GAC': 'D', 'GAA': 'E', 'GAG': 'E',
      'GGU': 'G', 'GGC': 'G', 'GGA': 'G', 'GGG': 'G'
  }

  protein_sequence = ""
  for i in range(0, len(rna_sequence), 3):
    codon = rna_sequence[i:i+3]

    if len(codon) < 3:
      break

    amino_acid=codon_table.get(codon)
    if amino_acid == '*':
      break

    if amino_acid is not None:
      protein_sequence += amino_acid
  return protein_sequence

rna_sequence = "AUGGCCAUGGCGCCCAGAACUGAGAUCAAUAGUACCCGUAUUA"
protein_sequence = translate_rna_to_protein(rna_sequence)
print(protein_sequence)
# Out:
# MAMAPRTEINSTRI

# %% [markdown]
# USING BIOPYTHON

# %%
from Bio.Seq import Seq

my_rna=Seq("AUGGCCAUGGCGCCCAGAACUGAGAUCAAUAGUACCCGUAUUA")

protein = my_rna.translate()

print("Original RNA Sequence:", my_rna)
print("Protein Sequence:", protein)
# Out:
# Original RNA Sequence: AUGGCCAUGGCGCCCAGAACUGAGAUCAAUAGUACCCGUAUUA
# Protein Sequence: MAMAPRTEINSTRI
# /usr/local/lib/python3.12/dist-packages/Bio/Seq.py:2877: BiopythonWarning: Partial codon, len(sequence) not a multiple of three. Explicitly trim the sequence or add trailing N before translation. This may become an error in future.
#   warnings.warn(
